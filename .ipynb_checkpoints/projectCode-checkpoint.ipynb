# %% [markdown]
# # Project Code

# %%
#imports 
import os 

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier



import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Load Data

# %%
path = os.getcwd() + '/data/cleanedRecipeData.csv'

data = pd.read_csv(path, header= 0)
print(data.shape)
data['ones'] = np.ones(data.shape[0])
X = data[['ones', 'OG','FG','ABV','IBU','Color']].values
y = data[['StyleID']].values
y = y.ravel()
print(X.shape, y.shape)
# Out:
# (66582, 18)
# 0        14
# 1        14
# 2         6
# 3         3
# 4        14
#          ..
# 66577    14
# 66578    26
# 66579    14
# 66580    21
# 66581    14
# Name: StyleID, Length: 66582, dtype: int64
# (66582, 6) (66582,)

# %% [markdown]
# ## Logistic Regression
#
# ### Split Data

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=0)

print(X_train.shape)
print(x_test.shape)
# Out:
# (56594, 6)
# (9988, 6)

# %% [markdown]
# ### Scale Features

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ### Build Model

# %%
model = LogisticRegression(max_iter = 4500)
model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=4500)

# %%
y_pred = model.predict(x_test)

# %%
conf_matrix = np.array(confusion_matrix(y_test, y_pred))
df = pd.DataFrame(conf_matrix)
#print(df)
plt.imshow(conf_matrix)

# %% [markdown]
# ### Performance

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00        48
#            2       0.00      0.00      0.00       294
#            3       0.00      0.00      0.00      1124
#            4       0.00      0.00      0.00        92
#            5       0.00      0.00      0.00       332
#            6       0.00      0.00      0.00       370
#            7       0.00      0.00      0.00       310
#            8       0.00      0.00      0.00        32
#            9       0.00      0.00      0.00        68
#           10       0.00      0.00      0.00       179
#           11       0.00      0.00      0.00       106
#           12       0.00      0.00      0.00        25
#           13       0.00      0.00      0.00        84
#           14       0.34      0.93      0.50      2585
#           15       0.00      0.00      0.00       125
#           16       0.00      0.00      0.00       640
#           17       0.00      0.00      0.00       103
#           18       0.00      0.00      0.00        84
#           19       0.00      0.00      0.00       184
#           20       0.00      0.00      0.00       415
#           21       0.00      0.00      0.00       199
#           22       0.00      0.00      0.00        21
#           23       0.00      0.00      0.00       584
#           24       0.00      0.00      0.00        63
#           25       0.31      0.89      0.46       923
#           26       0.00      0.00      0.00       217
#           27       0.00      0.00      0.00       409
#           29       0.00      0.00      0.00       372
#
#     accuracy                           0.32      9988
#    macro avg       0.02      0.06      0.03      9988
# weighted avg       0.12      0.32      0.17      9988
# C:\Users\deanp\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\deanp\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\deanp\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
styles = {}
for beer in data['Style']:
        try:
            styles[beer] += 1
        except:
            styles[beer] = 1
#print(styles)

fig1, ax1 = plt.subplots()
ax1.pie(styles.values(), labels=styles.keys(),autopct='%1.1f%%')
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()
# Out:
# {'IPA': 17064, 'Blond Ale': 2520, 'APA': 7581, 'Porter': 2700, 'Pilsner': 1216, 'Saison': 2617, 'Brown Ale': 1988, 'Lager': 4232, 'Strong Ale': 1495, 'Stout': 6169, 'Amber Ale': 2056, 'Kolsch': 869, 'Wheat Beer': 2338, 'Weisse': 2707, 'Belgian Style': 2140, 'ESB': 1286, 'Red Ale': 1349, 'Mead': 573, 'Smoked Beer': 438, 'Fruited Beer': 734, 'Marzen': 697, 'Helles': 649, 'Gose': 210, 'Cider': 199, 'Altbier': 312, 'Dunkel': 500, 'Barleywine': 594, 'West Coast Style': 1199, 'Rye Beer': 150}

# %% [markdown]
# # PCA

# %%
pca = PCA(n_components=2)
pca.fit(X)

print(pca.components_)
print(pca.explained_variance_)

pca = PCA(n_components=2)
projected = pca.fit_transform(X)
# Out:
# [[ 0.00000000e+00 -5.58245993e-05  5.10198542e-06  1.35944034e-02
#    9.99725264e-01  1.90941401e-02]
#  [-0.00000000e+00  2.85499610e-03  1.16663650e-03  3.83794672e-02
#   -1.96032877e-02  9.99066172e-01]]
# [1730.8458702  147.3570818]
# (66582, 6)
# (66582, 2)

# %%
plt.scatter(projected[:, 0], projected[:, 1],
            c=y, edgecolor='none', alpha=0.5,
            cmap=plt.cm.get_cmap('nipy_spectral', 10))
plt.xlabel('component 1')
plt.ylabel('component 2')
plt.colorbar();

# %% [markdown]
# # Random Forest

# %%
model = RandomForestClassifier()
model.fit(X_train,y_train)
accuracy=model.score(X_test,y_test)
print("Accuracy: ",accuracy)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-76-d93a13e6edb6> in <module>
#       1 model = RandomForestClassifier()
# ----> 2 model.fit(X_train,y_train)
#       3 accuracy=model.score(X_test,y_test)
#       4 print("Accuracy: ",accuracy)
#
# ~\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in fit(self, X, y, sample_weight)
#     302                 "sparse multilabel-indicator for y is not supported."
#     303             )
# --> 304         X, y = self._validate_data(X, y, multi_output=True,
#     305                                    accept_sparse="csc", dtype=DTYPE)
#     306         if sample_weight is not None:
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     431                 y = check_array(y, **check_y_params)
#     432             else:
# --> 433                 X, y = check_X_y(X, y, **check_params)
#     434             out = X, y
#     435
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     829         y = y.astype(np.float64)
#     830
# --> 831     check_consistent_length(X, y)
#     832
#     833     return X, y
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_consistent_length(*arrays)
#     260     uniques = np.unique(lengths)
#     261     if len(uniques) > 1:
# --> 262         raise ValueError("Found input variables with inconsistent numbers of"
#     263                          " samples: %r" % [int(l) for l in lengths])
#     264
#
# ValueError: Found input variables with inconsistent numbers of samples: [40857, 56594]
